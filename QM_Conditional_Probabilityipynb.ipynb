# %% [markdown]
# <a href="https://colab.research.google.com/github/ThomasTranGithub/CFA.Level.1.Study/blob/main/QM_Conditional_Probabilityipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CONDITIONAL AND JOINT PROBABILITY**
#
# **Learning Outcomes**
#
# * calculate and interpret conditional probabilities
# demonstrate the application of the multiplication and addition rules for probability
#
# * compare and contrast dependent and independent events
#
# * calculate and interpret an unconditional probability using the total probability rule
#
# * To understand the meaning of a probability in investment contexts, we need to distinguish between two types of probability: unconditional and conditional.
#
# * Both unconditional and conditional probabilities satisfy the definition of probability stated earlier, but they are calculated or estimated differently and have different interpretations. They provide answers to different questions.

# %% [markdown]
# **unconditional probability**
#
# * What is the probability of even A?
#
# P(A)
#
# * What is the probability that the stock earns a return above the risk free rate (event A)?
#
#
# The anser is an unconditional probability that can be viewed as the ratio of two quantities. The numerator is the sum of the probabilities of stock returns above the risk-free rate.
#
# * Contrast the question " What is the probability of A, given that B has occured?"
#
# P(A|B) ("The probability of A given B").

# %% [markdown]
# * Probability that the stock earns a return above the risk-free rate (event A).
#
# * given that the stock earns a positive return (event B)
#
# P( stock earns a return aboive rF rate| the stock earns a positive return)

# %% [markdown]
# **given that** is a restriction

# %% [markdown]
# The conditional probability calculated as the ratio of two quantitities.
#
# **Joint probability** - the event of both A and B happening is a joint probability. A and B are different from A give

# %% [markdown]
# **Definition of Conditional Probability.**
#
# * **The conditional probability** of A given that B has occurred is equal to the joint probability of A and B divided by the probability of B (assumed not to equal 0).
#
# * P(A | B) = P(AB)/P(B), P(B) ≠ 0

# %% [markdown]
# **multipilcation rule for probability**
#
# The joint probability of A and B can be expressed as
# P(AB) = P(A | B)P(B)

# %% [markdown]
# When we have two events A and B, that we are interested in we often want to know the probability that either A or B.
#
# OR is inclusive
#
# meaning that either A OR b occurs.
#
# **Addition Rule for Probabilities**
#
# * Given events A and B, the probability that A occurs, plus ( +, OR ) the probability that B occurs, minus the probability that both A and b occur.
#
# P( A or B) = P(A) + P(B) - P(AB)

# %% [markdown]
# /wmx-api-production/courses/51031/images/CFA0126-R-EXH4.png

# %% [markdown]
# /wmx-api-production/courses/51031/images/CFA0126-R-EXH5.png

# %% [markdown]
# ![CFA0126-R-EXH4.png](data:image/png;base64,...)

# %% [markdown]
# **Independence and Dependence**
#
# * Two events are independent if th eoccurence of one event does not affect the probability of occurence of the other event.
#
# * Two evens A and b are independent if and only if P( A|B) = P(A)  or, equivalently, P(B|A) = P(B)

# %% [markdown]
# * A and B are independent if the conditional probability of A given b is the same as the unconditional probability of A, P(A).
#
# * Independence means that knowing B tells you nothing about B.

# %% [markdown]
# **Dependent**
#
# * The probability of occurence of one is related to the occurence of the other.
#
# * When two events are independent, the multiplication rule for probabilities.
#
# **Multiplication Rule for Independent Events**
# * When two events are independent, the joint probability of A and B equals the product of the individual proabilities of A and B.
#
# * P(AB) = P(A)P(B)

# %% [markdown]
# * We formulate scenarios that we think affect the likelihood of an event that interests us.
#
# * We then estimate the proability of the event, given the scenario.
#
# * When the scenarios are mutally exclusive and exhaustive, no possible outcomes are left out.
#
# * We can analyze th eeven using the **total probability rule**.

# %% [markdown]
# **If we havce an even or scenario S, the event not-S, called the complement of S is written as S^C. Note that P(S) + P(S^C) = 1.**

# %% [markdown]
# **Total Probability Rule**
#
# * P(A)=P(AS) + P(AS^C)
#
# * = P(A|S)P(S) + P(A|S^C)P(S^C)
# P(A)=P(AS_1)+P(AS_2)+…+P(AS_n)
#
# * = P(A|S_1)P(S_1) + P(A|S_2)P(S_2)+…+ P(A|S_n)P(S_n)
#
# where S_1, S_2, …, S_n are mutually exclusive and exhaustive scenarios or events.

# %% [markdown]
# ![CFA0126-R-EXH6.png](data:image/png;base64,...)
