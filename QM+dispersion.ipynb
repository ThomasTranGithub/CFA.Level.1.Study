# %% [markdown]
# <a href="https://colab.research.google.com/github/ThomasTranGithub/CFA.Level.1.Study/blob/main/QM%2Bdispersion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Dispersion** measures the variability around a mean.
# Dispersions measures the risk.
#
# **Absolute Dispersion**
#
# The amount of variablity present without comparision to any reference point or benchmark.
#
# The variance or standard deviation of return is often used as a measure of risk pioneered by Harry Markowitz.
#
# **Range**
# The diffeence between the maximum and minimum values in a dataset
#
# ```
# dataset = [1, 2, 3, 4, 5]
# Maxvalue = numpy.amax(dataset)
# Minvalue = numpy.amin(dataset)
#
# Range = Maxvalue - Minvalue
#
# return(Range)
# ```
#
# **Mean Absolute Deviation**

# %%
def mean_absolute_deviation(values):
    mean = 4.5
    deviation_sum = 0

    for value in values:
        deviation_sum += abs(value - mean)

    mean_deviation = deviation_sum / len(values)
    return mean_deviation

# Example usage
data = [-11]
mad = mean_absolute_deviation(data)
print("Mean Absolute Deviation:", mad)
# Out:
# Mean Absolute Deviation: 15.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Sample Variance Formula**

# %% [markdown]
# Dispersion and the Relationship between the Arithmetic and the Geometric Means
# We can use the sample standard deviation to help us understand the gap between the arithmetic mean and the geometric mean. The relation between the arithmetic mean (X)
#  and geometric mean (X_G)
#  is:
# X_g - X = S**2/n
